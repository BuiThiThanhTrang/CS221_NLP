# %%
import torch
import torch.nn as nn
import torch.optim as optim
import sys
import os

# 1. Thêm đường dẫn thư mục repo vào sys.path
repo_path = "/content/drive/MyDrive/CS221_NLP/CS221_NLP"
print(repo_path)
if repo_path not in sys.path:
    sys.path.append(repo_path)
    print(f"Đã thêm {repo_path} vào sys.path")
# Out:
# /content/drive/MyDrive/CS221_NLP/CS221_NLP
# Đã thêm /content/drive/MyDrive/CS221_NLP/CS221_NLP vào sys.path

# %% [markdown]
# ## data preparation

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Load data from csv file

# %%
# Load data
df = pd.read_csv("/content/drive/MyDrive/CS221_NLP/data/data_train.csv")
df.head()
df.columns
# Out:
# Index(['text', 'label'], dtype='object')

# %%
x = df['text']
y = df['label']


#train_test_split(x, y, test_size=test_size, stratify=y,random_state=42)

# %% [markdown]
# ### Preprocessing data

# %%
# Filling nan rows

df.loc[13423] = ['None', 1]
df.loc[13424] = ['None', 0]
print(df[df.isna().any(axis=1)])
# Out:
# Empty DataFrame
# Columns: [text, label]
# Index: []

# %%
import pandas as pd

# def clean_by_majority_vote(x, y):
#     """
#     Lọc trùng lặp bằng cách giữ lại nhãn xuất hiện nhiều nhất cho mỗi text.
#     """
#     df = pd.DataFrame({'text':x, 'label': y})
#     counts = df.groupby(['text', 'label']).size().reset_index(name='count')
#     counts = counts.sort_values(['text', 'count'], ascending=[True, False])

#     df_deduped = counts.drop_duplicates(subset=['text'], keep='first')
#     return df_deduped[['text', 'label']]

# df_voted = clean_by_majority_vote(x, y)

# %% [markdown]
# ### Import and train model

# %%
# 2. Import class Model từ file model.py
from model import model, model1
print("Import model thành công!")
# Out:
# Import model thành công!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
test_size = 0.2
# x = df_voted['text']
# y = df_voted['label']
X_train, X_test, y_train, y_test = x, x, y, y

# %%
my_model = model()

my_model.fit(X_train, y_train)
print(list(X_train))
y_pred = my_model.predict(X_test)
print(f"accuracy: {accuracy_score(y_test, y_pred)}")
# Out:
# ['!!!', '!!!!!', '!!!!!!!', '!!!!!!!!!', '!!!!!!!!!!!!!', '!!!!!!!!!!!!!!!!!!"@T_Madison_x:', '!!!!!!"@__BrighterDays:', '!!!!&#8220;@selfiequeenbri:', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"', '"&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;@VandalSavage_:', '"&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;&#128514;@DaHomieFuzz:', '"&#128514;&#128514;&#128514;@The_Paradox:', '"&amp;', '"...Son', '"..All', '"@2015seniorprobs:', '"@A7XDemery:', '"@ARIZZLEINDACUT:', '"@Addicted2Guys:', '"@AdoreBellaaa:', '"@AdoreZoey:', '"@AllAboutManFeet:', '"@Allyhaaaaa:', '"@Almightywayne__:', '"@Almightywayne__:', '"@ArizonasFinest6:', '"@AutoWorId:', '"@BOSSBYTCHH:', '"@BRO_HEN314:', '"@BVSEDCHINK:', '"@BabyAnimalPics:', '"@Bay
# ...

# %% [markdown]
# ### Testing
