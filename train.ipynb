# %%
import torch
import torch.nn as nn
import torch.optim as optim
import sys
import os

# 1. Thêm đường dẫn thư mục repo vào sys.path
repo_path = "/content/drive/MyDrive/CS221_NLP/CS221_NLP"
print(repo_path)
if repo_path not in sys.path:
    sys.path.append(repo_path)
    print(f"Đã thêm {repo_path} vào sys.path")
# Out:
# /content/drive/MyDrive/CS221_NLP/CS221_NLP
# Đã thêm /content/drive/MyDrive/CS221_NLP/CS221_NLP vào sys.path

# %%
# 2. Import class Model từ file model.py
from model import model
print("Import model thành công!")
# Out:
# Import model thành công!

# %% [markdown]
# data preparation

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("/content/drive/MyDrive/CS221_NLP/data/val_df.csv")
df.head()
# Out:
#       id                                               text  label sentiment
# 0    317  Laying in bed til workkk... Oh the life. Defin...      0  negative
# 1  24292   ooohhh imma need you to get on that asap love...      2  positive
# 2   3513   Thanks! I love it they have a video, so you d...      2  positive
# 3   4322     I left my ipod in the car so now its all warm.      2  positive
# 4   6203  Great app. Only complaint is that I'd like the...      2  positive

# %%
df.drop(['id', 'sentiment'], axis = 1, inplace = True)
df.columns
# Out:
# Index(['text', 'label'], dtype='object')

# %%
x = df['text']
y = df['label']

test_size = 0.2

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=test_size, stratify=y)

# %%
my_model = model()

my_model.fit(X_train, y_train)
y_pred = my_model.predict(X_test)
print(f"accuracy: {accuracy_score(y_test, y_pred)}")
# Out:
# accuracy: 0.5859750240153698
